# %%
# Problem 1: Mobile Recharge Validation System

def validate_recharge():
    valid_plans = [199, 299, 399, 599]

    while True:
        try:
            amount = int(input("Enter recharge amount: ₹"))

            if amount < 50:
                print("Minimum recharge amount should be ₹50.")
            elif amount not in valid_plans:
                print("Invalid plan. Valid plans are:", valid_plans)
            else:
                print("Recharge successful for plan ₹", amount)
                break
        except ValueError:
            print("Please enter a valid numeric amount.")

# Run function
validate_recharge()
# Out:
# Recharge successful for plan ₹ 299

# %%
# Problem 2: Inventory Reorder Alert System

def check_inventory(stock_dict):
    for product, quantity in stock_dict.items():
        if quantity < 15:
            print(f"Reorder Alert: {product} (Stock: {quantity})")
        else:
            print(f"Stock OK: {product} (Stock: {quantity})")

# Example inventory
inventory = {
    "Apples": 10,
    "Bananas": 20,
    "Oranges": 8,
    "Mangoes": 25
}

check_inventory(inventory)
# Out:
# Reorder Alert: Apples (Stock: 10)
# Stock OK: Bananas (Stock: 20)
# Reorder Alert: Oranges (Stock: 8)
# Stock OK: Mangoes (Stock: 25)

# %%
# Problem 3: Student Result Processing System

def process_student_result(marks):
    total = 0
    for m in marks:
        total += m
    
    average = total / len(marks)
    print("Average Marks:", average)
    
    if average >= 50:
        return "Pass"
    else:
        return "Fail"

# Example usage
marks_list = [60, 55, 70, 45, 50]
result = process_student_result(marks_list)
print("Result:", result)
# Out:
# Average Marks: 56.0
# Result: Pass

# %%
# Problem 4: Cab Fare Estimator with Retry Option

def calculate_fare(distance, peak=False):
    base_fare = 50
    per_km_rate = 12
    fare = base_fare + (distance * per_km_rate)
    
    if peak:
        fare *= 1.25  # 25% extra
    
    return fare

while True:
    try:
        km = float(input("Enter distance in km: "))
        peak_input = input("Is it peak hour? (yes/no): ").lower()
        
        peak = True if peak_input == "yes" else False
        total_fare = calculate_fare(km, peak)
        
        print(f"Total Fare: ₹{total_fare:.2f}")
        break
    except ValueError:
        print("Please enter valid numeric distance.")
# Out:
# Total Fare: ₹650.00

# %%
# Problem 5: Employee Attendance Eligibility Checker

def check_attendance(attendance_list):
    present_days = 0
    
    for day in attendance_list:
        if day.upper() == "P":
            present_days += 1
    
    percentage = (present_days / len(attendance_list)) * 100
    print("Attendance Percentage:", percentage, "%")
    
    if percentage >= 75:
        return "Eligible"
    else:
        return "Not Eligible"

# Example usage
attendance = ["P", "A", "P", "P", "A", "P", "P", "P"]
status = check_attendance(attendance)
print("Eligibility Status:", status)
# Out:
# Attendance Percentage: 75.0 %
# Eligibility Status: Eligible

# %%
# Problem 6: Password Strength Checker

def check_password_strength(password):
    has_digit = False
    has_special = False
    special_chars = "@#$"
    
    if len(password) < 8:
        return "Weak Password: Minimum length should be 8"
    
    for ch in password:
        if ch.isdigit():
            has_digit = True
        if ch in special_chars:
            has_special = True
    
    if has_digit and has_special:
        return "Strong Password "
    else:
        return "Weak Password (Must include a digit and special character @#$)"

# Example usage
pwd = input("Enter your password: ")
print(check_password_strength(pwd))
# Out:
# Weak Password: Minimum length should be 8
